# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import adfuller
df=pd.read_csv('/content/airline-passengers.csv')
X=df.values
print(X)
result= adfuller(['1949-01', 112],['1949-01', 112])
print(result)
print('ADF Statistics:%f'%result[0])
print('p-value:%f'%result[1])
print('Critical Values:')
for key, value in result [4].item():
    print('\t%s:%.3f'%(key,value))
if result[0]<result[4]["5%"]:
   print("Reject Null hypothesis-so the data is stationary")
else:
   print("Fail to reject numm hypothesis-so the data is not stationary")
# Out:
# [['1949-01' 112]
#  ['1949-02' 118]
#  ['1949-03' 132]
#  ['1949-04' 129]
#  ['1949-05' 121]
#  ['1949-06' 135]
#  ['1949-07' 148]
#  ['1949-08' 148]
#  ['1949-09' 136]
#  ['1949-10' 119]
#  ['1949-11' 104]
#  ['1949-12' 118]
#  ['1950-01' 115]
#  ['1950-02' 126]
#  ['1950-03' 141]
#  ['1950-04' 135]
#  ['1950-05' 125]
#  ['1950-06' 149]
#  ['1950-07' 170]
#  ['1950-08' 170]
#  ['1950-09' 158]
#  ['1950-10' 133]
#  ['1950-11' 114]
#  ['1950-12' 140]
#  ['1951-01' 145]
#  ['1951-02' 150]
#  ['1951-03' 178]
#  ['1951-04' 163]
#  ['1951-05' 172]
#  ['1951-06' 178]
#  ['1951-07' 199]
#  ['1951-08' 199]
#  ['1951-09' 184]
#  ['1951-10' 162]
#  ['1951-11' 146]
#  ['1951-12' 166]
#  ['1952-01' 171]
#  ['1952-02' 180]
#  ['1952-03' 193]
#  ['1952-04' 181]
#  ['1952-05' 183]
#  ['1952-06' 218]
#  ['1952-07' 230]
#  ['1952-08' 242]
#  ['1952-09' 209]
#  ['1952-10' 191]
#  ['1952-11' 172]
#  ['1952-12' 194]
#  ['1953-01' 196]
#  ['1953-02' 196]
#  ['1953-03' 236]
#  ['1953-04' 235]
# ...

# %%
# imported adfull from statsmodel library
from statsmodels.tsa.stattools import adfuller
import pandas as pd
df = pd.read_csv('/content/daily-total-female-births.csv', header=0, index_col=0, squeeze=True)
# put all values in X variable
X = df.values
# app adfuller test on the data(x) and stored it in Result
result = adfuller(X)
print("printing of adf test all values:",result)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))

if result[0]< result[4]["5%"]:
	print("Rejected Null Hypothesis - so the time series is non stationary")
	# print("Fail to reject null hypothesis - so time series in stationary")
else:
	print("Rejected Null Hypothesis - so the time series is non stationary")
	# # print("Fail to reject null hypothesis - so time series in stationary")
# Out:
# printing of adf test all values: (-4.808291253559765, 5.2434129901498554e-05, 6, 358, {'1%': -3.448748905151901, '5%': -2.8696473721448728, '10%': -2.5710891239349585}, 2343.8290926464197)
# ADF Statistic: -4.808291
# p-value: 0.000052
# Critical Values:
# 	1%: -3.449
# 	5%: -2.870
# 	10%: -2.571
# Rejected Null Hypothesis - so the time series is non stationary

# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.stattools import adfuller
df=pd.read_csv('/content/airline-passengers1.csv')
X=df.values
result=adfuller(X)
print(result)
print('ADF Statistics:%f'%result[0])
print('p-value:%f'%result[1])
print('Critical Values:')
for key, value in result [4].item():
    print('\t%s:%.3f'%(key,value))
if result[0]<result[4]["5%"]:
   print("Reject Null hypothesis-so the data is stationary")
else:
   print("Fail to reject numm hypothesis-so the data is not stationary")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-4de7583828a0> in <module>()
#       4 df=pd.read_csv('/content/airline-passengers1.csv')
#       5 X=df.values
# ----> 6 result=adfuller(X)
#       7 print(result)
#       8 print('ADF Statistics:%f'%result[0])
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     234                          'deterministic regressors')
#     235     xdiff = np.diff(x)
# --> 236     xdall = lagmat(xdiff[:, None], maxlag, trim='both', original='in')
#     237     nobs = xdall.shape[0]
#     238
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/tsatools.py in lagmat(x, maxlag, trim, original, use_pandas)
#     402     if xa.ndim == 1:
#     403         xa = xa[:, None]
# --> 404     nobs, nvar = xa.shape
# ...
